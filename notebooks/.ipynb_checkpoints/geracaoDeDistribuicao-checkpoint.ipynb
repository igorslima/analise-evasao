# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics

import nbimporter
from sklearn.metrics import silhouette_samples, silhouette_score

from preprocessamento import *
from geracaoDeTabelas import gerar_todos_os_graficos
from sklearn.cluster import KMeans, DBSCAN
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA, LatentDirichletAllocation as LDA

from mpl_toolkits import mplot3d
# Out:
# Importing Jupyter notebook from preprocessamento.ipynb
# Importing Jupyter notebook from geracaoDeTabelas.ipynb

# %%
dados_2015 = pd.read_csv('../arquivos/2015.csv')
dados_2016 = pd.read_csv('../arquivos/2016.csv')

# %%
dados_csv = pd.concat([dados_2015, dados_2016])
# Out:
# /home/igor/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   """Entry point for launching an IPython kernel.

# %%
dados_csv.shape
# Out:
# (466, 55)

# %%
y_2015 = gerar_target(dados_2015)
y_2016 = gerar_target(dados_2016)

y = pd.concat([y_2015, y_2016])

# %%
df_2015 = preprocessar(dados_2015)
df_2016 = preprocessar(dados_2016)

frames = [df_2015, df_2016]

data_frame = pd.concat(frames)

# %%
data_frame.columns
# Out:
# Index(['filhos', 'afinidade_linguagens', 'afinidade_humanas',
#        'afinidade_matematica', 'afinidade_natureza', 'motivacao_curso',
#        'tarefa_durante_curso', 'realizacao_profissional',
#        'concluir_curso_nessa_instituicao', 'nao_mudaria_de_curso'],
#       dtype='object')

# %%
lista = ['Tem filhos?', 'Indique em que medida você tem afinidade com as áreas a seguir: [Ciências da natureza e suas tecnologias.]',
 'Indique em que medida você tem afinidade com as áreas a seguir: [Ciências humanas e suas tecnologias.]',
 'Indique em que medida você tem afinidade com as áreas a seguir: [Linguagens, códigos e suas tecnologias.]',
 'Indique em que medida você tem afinidade com as áreas a seguir: [Matemática e suas tecnologias.]']

# %%
dados = dados_csv[lista]

# %%
dados
# Out:
#     Tem filhos?  \
# 0           Não
# 1           Não
# 2           Não
# 3           Não
# 4           Não
# 5           Não
# 6           Não
# 7           Não
# 8           Não
# 9           Não
# 10          Não
# 11          Não
# 12          Não
# 13          Não
# 14          Não
# 15          Não
# 16          Não
# 17          Não
# 18          Não
# 19          Não
# 20          Não
# 21          Não
# 22          Não
# 23          Não
# 24          Não
# 25          Não
# 26          Sim
# 27          Não
# 28          Não
# 29          Não
# ..          ...
# 200         Não
# 201         Não
# 202         Não
# 203         Não
# 204         Não
# 205         Não
# 206         Não
# 207         Não
# 208         Não
# 209         Não
# 210         Não
# 211         Não
# 212         Não
# 213         Não
# 214         Não
# 215         Não
# 216         Não
# 217         Não
# 218         Não
# 219         Não
# 220         Não
# 221         Não
# 222         Não
# 223         Não
# 224         Não
# 225         Não
# 226         Não
# 227         Não
# 228         Não
# 229         Não
#
#     Indique em que medida você tem afinidade com as áreas a seguir: [Ciências da natureza e suas tecnologias.]  \
# 0                                      Muita afinidade
# 1                                      Muita afinidade
# 2                                        Boa afinidade
# 3                                     Alguma afinidade
# 4                                      Muita afinidade
# 5                                        Boa afinidade
# 6                                        Boa afinidade
# 7                                     Alguma afinidade
# 8                                     Alguma afinidade
# 9                                        Boa afinidade
# 10                               Pouquíssima afinidade
# 11                                       Boa afinidade
# 12                                     Muita afinidade
# 13                                       Boa afinidade
# 14                                    Alguma afinidade
# 15                                     Muita afinidade
# 16                                    Alguma afinidade
# 17                                       Boa afinidade
# 18                                     Muita afinidade
# 19                                       Boa afinidade
# 20                                     Muita afinidade
# 21                                       Boa afinidade
# 22                                       Boa afinidade
# 23                                       Boa afinidade
# 24                                     Muita afinidade
# 25                                       Boa afinidade
# 26                                    Alguma afinidade
# 27                                       Boa afinidade
# 28                                     Muita afinidade
# 29                                       Boa afinidade
# ..                                                 ...
# 200                                   Alguma afinidade
# 201                                   Alguma afinidade
# 202                                      Boa afinidade
# 203                                    Muita afinidade
# 204                                      Boa afinidade
# 205                              Pouquíssima afinidade
# 206                                      Boa afinidade
# 207                                      Boa afinidade
# 208                                    Muita afinidade
# 209                                      Boa afinidade
# 210                                      Boa afinidade
# 211                                      Boa afinidade
# 212                                   Alguma afinidade
# 213                                    Muita afinidade
# 214                                   Alguma afinidade
# 215                                    Muita afinidade
# 216                                   Alguma afinidade
# 217                                   Alguma afinidade
# 218                                      Boa afinidade
# 219                                   Alguma afinidade
# 220                                      Boa afinidade
# 221                                   Alguma afinidade
# 222                              Pouquíssima afinidade
# 223                                   Alguma afinidade
# 224                                      Boa afinidade
# 225                              Pouquíssima afinidade
# 226                                   Alguma afinidade
# 227                                      Boa afinidade
# 228                              Pouquíssima afinidade
# 229                                   Alguma afinidade
#
#     Indique em que medida você tem afinidade com as áreas a seguir: [Ciências humanas e suas tecnologias.]  \
# 0                                        Boa afinidade
# 1                                     Alguma afinidade
# 2                                     Alguma afinidade
# 3                                      Muita afinidade
# 4                                        Boa afinidade
# 5                                        Boa afinidade
# 6                                        Boa afinidade
# 7                                     Alguma afinidade
# 8                                     Alguma afinidade
# 9                                     Alguma afinidade
# 10                                       Boa afinidade
# 11                                       Boa afinidade
# 12                                    Alguma afinidade
# 13                                    Alguma afinidade
# 14                                       Boa afinidade
# 15                                     Muita afinidade
# 16                                    Alguma afinidade
# 17                                       Boa afinidade
# 18                                     Muita afinidade
# 19                                     Muita afinidade
# 20                                     Muita afinidade
# 21                                    Alguma afinidade
# 22                                    Alguma afinidade
# 23                                    Alguma afinidade
# 24                                       Boa afinidade
# 25                               Pouquíssima afinidade
# 26                                       Boa afinidade
# 27                                     Muita afinidade
# 28                                    Alguma afinidade
# 29                                       Boa afinidade
# ..                                                 ...
# 200                                   Alguma afinidade
# 201                                   Alguma afinidade
# 202                                      Boa afinidade
# 203                                   Alguma afinidade
# 204                              Pouquíssima afinidade
# 205                                   Alguma afinidade
# 206                                      Boa afinidade
# 207                                      Boa afinidade
# 208                                      Boa afinidade
# 209                                      Boa afinidade
# 210                              Pouquíssima afinidade
# 211                                      Boa afinidade
# 212                                      Boa afinidade
# 213                                    Muita afinidade
# 214                                   Alguma afinidade
# 215                                    Muita afinidade
# 216                                      Boa afinidade
# 217                                   Alguma afinidade
# 218                                      Boa afinidade
# 219                                      Boa afinidade
# 220                                      Boa afinidade
# 221                                    Muita afinidade
# 222                                   Alguma afinidade
# 223                                    Muita afinidade
# 224                                   Alguma afinidade
# 225                                   Alguma afinidade
# 226                              Pouquíssima afinidade
# 227                                      Boa afinidade
# 228                                      Boa afinidade
# 229                                    Muita afinidade
#
#     Indique em que medida você tem afinidade com as áreas a seguir: [Linguagens, códigos e suas tecnologias.]  \
# 0                                        Boa afinidade
# 1                                     Alguma afinidade
# 2                                Pouquíssima afinidade
# 3                                      Muita afinidade
# 4                                        Boa afinidade
# 5                                     Alguma afinidade
# 6                                        Boa afinidade
# 7                                Pouquíssima afinidade
# 8                                        Boa afinidade
# 9                                        Boa afinidade
# 10                                    Alguma afinidade
# 11                                    Alguma afinidade
# 12                                       Boa afinidade
# 13                                    Alguma afinidade
# 14                                       Boa afinidade
# 15                                       Boa afinidade
# 16                                     Muita afinidade
# 17                                    Alguma afinidade
# 18                                       Boa afinidade
# 19                                    Alguma afinidade
# 20                                       Boa afinidade
# 21                                       Boa afinidade
# 22                                    Alguma afinidade
# 23                                    Alguma afinidade
# 24                                       Boa afinidade
# 25                               Pouquíssima afinidade
# 26                                    Alguma afinidade
# 27                                       Boa afinidade
# 28                                       Boa afinidade
# 29                                       Boa afinidade
# ..                                                 ...
# 200                                      Boa afinidade
# 201                                      Boa afinidade
# 202                                      Boa afinidade
# 203                                      Boa afinidade
# 204                                   Alguma afinidade
# 205                              Pouquíssima afinidade
# 206                                      Boa afinidade
# 207                                   Alguma afinidade
# 208                                   Alguma afinidade
# 209                                   Alguma afinidade
# 210                                   Alguma afinidade
# 211                                   Alguma afinidade
# 212                                      Boa afinidade
# 213                                    Muita afinidade
# 214                                    Muita afinidade
# 215                                    Muita afinidade
# 216                                    Muita afinidade
# 217                              Pouquíssima afinidade
# 218                                      Boa afinidade
# 219                                    Muita afinidade
# 220                                    Muita afinidade
# 221                                      Boa afinidade
# 222                                      Boa afinidade
# 223                                      Boa afinidade
# 224                                   Alguma afinidade
# 225                                      Boa afinidade
# 226                                      Boa afinidade
# 227                                      Boa afinidade
# 228                                      Boa afinidade
# 229                                      Boa afinidade
#
#     Indique em que medida você tem afinidade com as áreas a seguir: [Matemática e suas tecnologias.]
# 0                                        Boa afinidade
# 1                                      Muita afinidade
# 2                                      Muita afinidade
# 3                                        Boa afinidade
# 4                                      Muita afinidade
# 5                                      Muita afinidade
# 6                                        Boa afinidade
# 7                                        Boa afinidade
# 8                                      Muita afinidade
# 9                                      Muita afinidade
# 10                                     Muita afinidade
# 11                                     Muita afinidade
# 12                                     Muita afinidade
# 13                                     Muita afinidade
# 14                                    Alguma afinidade
# 15                                       Boa afinidade
# 16                                       Boa afinidade
# 17                                    Alguma afinidade
# 18                                     Muita afinidade
# 19                                       Boa afinidade
# 20                                     Muita afinidade
# 21                                     Muita afinidade
# 22                                       Boa afinidade
# 23                                       Boa afinidade
# 24                                    Alguma afinidade
# 25                                     Muita afinidade
# 26                                       Boa afinidade
# 27                                       Boa afinidade
# 28                                     Muita afinidade
# 29                                       Boa afinidade
# ..                                                 ...
# 200                                    Muita afinidade
# 201                                   Alguma afinidade
# 202                                   Alguma afinidade
# 203                              Pouquíssima afinidade
# 204                                    Muita afinidade
# 205                                    Muita afinidade
# 206                                      Boa afinidade
# 207                                   Alguma afinidade
# 208                                    Muita afinidade
# 209                                    Muita afinidade
# 210                                    Muita afinidade
# 211                                      Boa afinidade
# 212                                   Alguma afinidade
# 213                                      Boa afinidade
# 214                                   Alguma afinidade
# 215                                      Boa afinidade
# 216                              Pouquíssima afinidade
# 217                              Pouquíssima afinidade
# 218                                   Alguma afinidade
# 219                              Pouquíssima afinidade
# 220                                      Boa afinidade
# 221                              Pouquíssima afinidade
# 222                              Pouquíssima afinidade
# 223                              Pouquíssima afinidade
# 224                                    Muita afinidade
# 225                              Pouquíssima afinidade
# 226                                      Boa afinidade
# 227                                   Alguma afinidade
# 228                                      Boa afinidade
# 229                                   Alguma afinidade
#
# [466 rows x 5 columns]

# %%
def gerar_graficos(dados, coluna, cluster):
    data = dados[coluna].value_counts()
    data.plot(kind='barh', title=coluna,figsize=(17, 9))
    print(data)
    plt.savefig('../imagens/2015_2016/todos/' + coluna + '.jpg')
    
def gerar_todos_graficos(cluster, nome_cluster):
    for coluna in cluster.columns:
        gerar_graficos(cluster, coluna, nome_cluster)
